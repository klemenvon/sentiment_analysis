# %%
import  requests
import json

# %%
def scrape_steam_reviews(app_id, params):
    """
    Scrapes Steam reviews for a given app ID.

    Args:
        app_id (str): The Steam app ID.
        params (dict): A dictionary of parameters to pass to the API.

    Returns:
        dict: A dictionary containing the JSON response from the API.
    """
    url = f"https://store.steampowered.com/appreviews/{app_id}"
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error during request: {e}")
        return None
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return None

# %%
app_id = "1245620"  # Elden Ring App ID
params = {
    "json": "1" # added json parameter
}

data = scrape_steam_reviews(app_id, params)

if data:
    print(json.dumps(data, indent=4))  # Pretty print the JSON
else:
    print("Failed to retrieve or process data.")
# Out:
# {
#     "success": 1,
#     "query_summary": {
#         "num_reviews": 20,
#         "review_score": 8,
#         "review_score_desc": "Very Positive",
#         "total_positive": 375793,
#         "total_negative": 23093,
#         "total_reviews": 398886
#     },
#     "reviews": [
#         {
#             "recommendationid": "191004925",
#             "author": {
#                 "steamid": "76561198199095678",
#                 "num_games_owned": 57,
#                 "num_reviews": 15,
#                 "playtime_forever": 4739,
#                 "playtime_last_two_weeks": 1882,
#                 "playtime_at_review": 4739,
#                 "last_played": 1742748349
#             },
#             "language": "english",
#             "review": "For someone who has never played a souls game, I was impressed at how this game has a massive open world with a cryptic story-line and different endings based on different actions performed.  The hardest part of this game wasn't facing the demigods with supernatural powers, it was overcoming my fear of giant flying insects and my fear of heights by playing this game. Thanks to this game, I no longer have acrophobia and entomophobia.\n\n10/10 would recommend to overcome your fears.",
#             "timestamp_created": 1742748749,
#             "timestamp_updated": 1742748749,
#             "voted_up": true,
#             "votes_up": 25,
#             "votes_funny": 3,
#             "weighted_vote_score": "0.723893582820892334",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191460314",
#             "author": {
#                 "steamid": "76561198045112814",
#                 "num_games_owned": 110,
#                 "num_reviews": 12,
#                 "playtime_forever": 1726,
#                 "playtime_last_two_weeks": 349,
#                 "playtime_at_review": 1726,
#                 "last_played": 1742659140
#             },
#             "language": "english",
#             "review": "[h1][b]Elden Ring - Where Beauty Meets Brutality (and My Pride Gets Repeatedly Punched)[/b][/h1]\n\nOh, Elden Ring. What a masterpiece you are! FromSoftware has truly outdone themselves with this one\u2014like they handed Picasso a game engine and said, \"Make something that'll make people cry.\" And boy, does it make you cry rivers.\n\nThe graphics? [b]Stunning.[/b] Seriously, I\u2019ve spent more time staring at the sunset over Limgrave than actually playing the game. The landscapes are so breathtakingly beautiful that every time I respawn after dying to some random frog or pot-wielding grandma, I feel like I\u2019m in an art gallery where someone keeps punching me in the face. It\u2019s poetic. Truly poetic.\n\nAnd the gameplay? Stellar. The combat system is tight, responsive, and deeply satisfying when you finally nail that perfect parry against a giant knight who's been curb-stomping you for hours. Every victory feels earned, even if it took me 47 tries to beat a tree stump that might have been sentient. There\u2019s just something magical about going from \u201cI hate everything\u201d to \u201cI am the Elden Lord!\u201d in under five seconds.\n\nNow let\u2019s talk about the difficulty. Oh, sweet merciful heavens, this game is brutal. But here\u2019s the twist\u2014it\u2019s fun! Like, really fun. Sure, I\u2019ve screamed at my screen more times than I can count because yet another invisible skeleton decided to ruin my day, but there\u2019s always this little voice inside me saying, \u201cCome on, you got this!\u201d [i]Spoiler alert: I didn\u2019t get this.[/i] Not most of the time anyway. But hey, dying is half the experience, right? [i]Right?![/i]\n\nIn conclusion, Elden Ring is a love letter to gamers who enjoy being humbled by their own incompetence while marveling at jaw-dropping visuals and flawless mechanics. If you\u2019re looking for a challenge that\u2019ll test your patience, skill, and will to live, look no further. Just be prepared to lose a few hundred hours of your life\u2014and possibly your sanity\u2014to a video game that somehow makes failure feel rewarding.",
#             "timestamp_created": 1743246325,
#             "timestamp_updated": 1743246346,
#             "voted_up": true,
#             "votes_up": 5,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.583333313465118408",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191743794",
#             "author": {
#                 "steamid": "76561199007874518",
#                 "num_games_owned": 223,
#                 "num_reviews": 33,
#                 "playtime_forever": 7670,
#                 "playtime_last_two_weeks": 3535,
#                 "playtime_at_review": 7047,
#                 "last_played": 1743688730
#             },
#             "language": "english",
#             "review": "[h2] Honest Review [/h2]\nPeak game, after approx 110++ hours i finally become the elden ring. It is a classic soulslike game the plus is you got all variant and playstyle. While DS series seems to be a melee based combat, at least for me. Elden ring step up so magic, melee, bow, etc playable. \n\nTLDR : git gud for me\n\n[h2] What can be improved?[/h2]\nI would say that i crazily simp for Rya. Kinda dissapointing that they don't include Rya ending's. This alone make the game a  9/10. Hopefully they do an update to include Rya as one of the ending.",
#             "timestamp_created": 1743531423,
#             "timestamp_updated": 1743531423,
#             "voted_up": true,
#             "votes_up": 3,
#             "votes_funny": 1,
#             "weighted_vote_score": "0.552590250968933105",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "190408547",
#             "author": {
#                 "steamid": "76561198049009386",
#                 "num_games_owned": 9246,
#                 "num_reviews": 75,
#                 "playtime_forever": 7356,
#                 "playtime_last_two_weeks": 0,
#                 "playtime_at_review": 7356,
#                 "last_played": 1679748750
#             },
#             "language": "english",
#             "review": "This is the first Souls-like game I have ever played. I was a bit skeptical about it, but everything changed as soon as I started the game.\n\nThe game felt hard at the beginning, but once you understand what needs to be done, how the combat mechanics work, and study the difficult bosses after a few deaths, it becomes much more enjoyable.\n\nThe universe FromSoftware created is beautiful, with great level design and well-crafted bosses. There are a few repetitive dungeons, areas, and bosses, and at times the game feels a bit stretched, but I can tolerate that because it's not overdone.\n\nThere is a huge variety of builds and weapons, which is very useful if you plan to have more than one playthrough. On top of that, the game offers a vast number of hidden collectibles and secrets.\n\nIt's a very special game, and I would highly recommend it to action-adventure RPG lovers. This isn't structured exactly like previous Souls games, you have a massive open-world map with stunning locations and excellent level design.",
#             "timestamp_created": 1742163284,
#             "timestamp_updated": 1742163284,
#             "voted_up": true,
#             "votes_up": 6,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.54445958137512207",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191088636",
#             "author": {
#                 "steamid": "76561198007716247",
#                 "num_games_owned": 0,
#                 "num_reviews": 14,
#                 "playtime_forever": 4319,
#                 "playtime_last_two_weeks": 3790,
#                 "playtime_at_review": 2682,
#                 "last_played": 1743501455
#             },
#             "language": "english",
#             "review": "fantastic game. played it for 250+ hours on PS5 on release.\r\n\r\nbut, 3 years later, there are some obvious problems that reduce my enjoyment:\r\n\r\n- mouse/keyboard controls are awful. cycling through abilities/items is tedious. why can't there be a hotbar (i.e. keys 1-9) for that? this is clearly a game made for controller, explicitly for controllers with back paddles (unless you want to \"claw grip\". ouch.)\r\n- no quest log, really? i can't remember what some random NPC told me 10-20 hours ago. i don't need quest markers, just a log where i can read up on what the NPCs said. if it isn't in-game people will just look it up on the internet.\r\n- no maps in dungeons. again, people will just look it up on the internet.\r\n- UI-\"Toasts\" must be dismissed manually, even in combat. wtfman!\r\n- \"just run past 90% of the enemies\" gameplay.\r\n- \"the princess is in another castle\" moment after the first time reaching the erdtree.\r\n- skeletons are cumbersome without certain weapons (Golden Epitaph etc.)\r\n- lots of unfair and cheesy enemy attacks that stunlock you to death.\r\n- lock-on system is bad, especially against larger enemies.\r\n- sometimes questionable hit box detection.\r\n- the worst enemy is the camera.\r\n- \"catch flame\" is still OP :)\r\n\r\nbut, still a 9/10 and a must-play. the art-/characterdesign is superb, the music is brilliant, exploration gets rewarded and riding torrent feels just good. also, there are quite a bunch of good mods for the PC version.",
#             "timestamp_created": 1742838093,
#             "timestamp_updated": 1742838093,
#             "voted_up": true,
#             "votes_up": 3,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.542483627796173096",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191123689",
#             "author": {
#                 "steamid": "76561198363109630",
#                 "num_games_owned": 167,
#                 "num_reviews": 35,
#                 "playtime_forever": 1589,
#                 "playtime_last_two_weeks": 1589,
#                 "playtime_at_review": 641,
#                 "last_played": 1743666640
#             },
#             "language": "english",
#             "review": "As amazing as everyone says. Great visuals, fun combat, and a fantastic soundtrack. My favorite thing about the game, is the incredibly deep character creation options, the possibilities are nearly endless. Playing with friends is a true Joy, and I can't recommend this game enough!",
#             "timestamp_created": 1742873669,
#             "timestamp_updated": 1742873669,
#             "voted_up": true,
#             "votes_up": 2,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.542168676853179932",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "190816321",
#             "author": {
#                 "steamid": "76561199236995420",
#                 "num_games_owned": 26,
#                 "num_reviews": 2,
#                 "playtime_forever": 15241,
#                 "playtime_last_two_weeks": 117,
#                 "playtime_at_review": 15123,
#                 "last_played": 1743265850
#             },
#             "language": "english",
#             "review": "---{ Graphics }---\n\u2610 You forget what reality is\n\u2611 Beautiful\n\u2610 Good\n\u2610 Decent\n\u2610 Bad\n\u2610 Don\u2018t look too long at it\n\u2610 MS-DOS\n\n---{ Gameplay }---\n\u2611 Very good\n\u2610 Good\n\u2610 It's just gameplay\n\u2610 Mehh\n\u2610 Watch paint dry instead\n\u2610 Just don't\n\n---{ Audio }---\n\u2610 Eargasm\n\u2611 Very good\n\u2610 Good\n\u2610 Not too bad\n\u2610 Bad\n\u2610 I'm now deaf\n\n---{ Audience }---\n\u2610 Kids\n\u2611 Teens\n\u2611 Adults\n\u2610 Grandma\n\n---{ PC Requirements }---\n\u2610 Check if you can run paint\n\u2610  Potato\n\u2611 Decent\n\u2610 Fast\n\u2610 Rich boi\n\u2610 Ask NASA if they have a spare computer\n\n---{ Difficulty }---\n\u2610 Just press 'W'\n\u2610 Easy\n\u2610 Easy to learn / Hard to master\n\u2610 Significant brain usage\n\u2611 Difficult\n\u2610 Dark Souls\n\n---{ Story }---\n\u2610 No Story\n\u2610 Some lore\n\u2610 Average\n\u2610 Good\n\u2610 Lovely\n\u2611 It'll replace your life\n\n---{ Game Time }---\n\u2610 Long enough for a cup of coffee\n\u2610 Short\n\u2610 Average\n\u2611 Long\n\u2610 To infinity and beyond\n\n---{ Price }---\n\u2610 It's free!\n\u2611 Worth the price\n\u2610 If it's on sale\n\u2610 If u have some spare money left\n\u2610 Not recommended\n\u2610 You could also just burn your money\n\n---{ Bugs }---\n\u2610 Never heard of\n\u2611 Minor bugs\n\u2610 Can get annoying\n\u2610 ARK: Survival Evolved\n\u2610 The game itself is a big terrarium for bugs\n",
#             "timestamp_created": 1742576484,
#             "timestamp_updated": 1742576484,
#             "voted_up": true,
#             "votes_up": 2,
#             "votes_funny": 1,
#             "weighted_vote_score": "0.541984736919403076",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "190326624",
#             "author": {
#                 "steamid": "76561197970525021",
#                 "num_games_owned": 458,
#                 "num_reviews": 97,
#                 "playtime_forever": 1983,
#                 "playtime_last_two_weeks": 996,
#                 "playtime_at_review": 251,
#                 "deck_playtime_at_review": 251,
#                 "last_played": 1743682365
#             },
#             "language": "english",
#             "review": "Don't lisyen to people who try to shame you for not liking games that are too hard for you. If you like the challenge, go for it, make it hard. If you don't, you have options to make life easier. This game gives you the tools to tailor the game to your preferences and you should use things as you see fit. \r\nThe gameplay is a bit stiff and clunky. Kind of like an indie title using stock plugins. Not bad so much as needing an adjustment period. The graphics are nothing special and the pacing glacial.\r\nWhat this game has going against it, however, pales in comparison to the whole. As a package, it's so, so hard to dislike this. The atmosphere keeps you hooked, the design of the spaces makes you cautious, yet still willing to push on. Any setbacks you have can be put off while you work on getting stronger and still engaging with the game fully. The side quests are not, they are all integral to the whole.\r\nTruly a game that is not for everybody, yet appealing to so, so many. Some people may put you off, but please remember that your game is yours. Play it how you enjoy it.",
#             "timestamp_created": 1742099147,
#             "timestamp_updated": 1742099147,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.528301894664764404",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": true
#         },
#         {
#             "recommendationid": "190730897",
#             "author": {
#                 "steamid": "76561197984170060",
#                 "num_games_owned": 866,
#                 "num_reviews": 256,
#                 "playtime_forever": 23931,
#                 "playtime_last_two_weeks": 81,
#                 "playtime_at_review": 23764,
#                 "last_played": 1742509265
#             },
#             "language": "english",
#             "review": "I really enjoyed my time in this game. I spent about 400 hours on a _single_ playthrough, and not a moment of it felt like it dragged or overstayed its welcome, nor did the hours matter at all. \r\n\r\nThe landscapes were gorgeous and unique, each one filled me with a tapestry of emotions \u2014 curiosity, dread, expectation, apprehension, anticipation, excitement, fear, the whole gamut. It's a unique mix that I haven't experienced in other games. \r\n\r\nThe world constantly unveiled surprises around every corner, and the game would have a subtle way of defying the things I would begin to treat as expected; just when I think I've managed to 'figure out' a certain enemy type or a zone, a new variation is thrown at me that I have to overcome. \r\n\r\nConquering these challenges felt rewarding, but right away became a baseline setup for the next challenge to overcome. I realize a lot of this is quite abstract and intangible but I had to express it, and I see the other reviews also trying to do the same thing. \r\n\r\nThe type of environment that really appeals to me is being alone (I don't like playing with others), I like rich fantasy landscapes, I like castles and dungeons, ruins, exploring, finding secrets. This world gives me all of that. There's a pervasive sense of exploration and loneliness, within a realm that is hostile and beautiful. The accompanying music is often tenuous and haunting, enhancing the atmospheric experience. \r\n\r\nThe other really nice thing about the game, is I can play it and 'beat' it in so many different ways. There are so many tools available and it's entirely up to me whether to use or ignore them, and that makes for a unique playthrough. There are dozens of weapons, armor types, spells, skills, summons, recipes. I simply chose the playstyle that I liked the most. I didn't really go for consumables, but I did like summons. I found lots of cool looking weapons, but only the pickaxe felt the best to me, the way it just smacks the enemies down with absolute piercing authority.",
#             "timestamp_created": 1742496650,
#             "timestamp_updated": 1742496650,
#             "voted_up": true,
#             "votes_up": 2,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.52649378776550293",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "190966366",
#             "author": {
#                 "steamid": "76561199122290030",
#                 "num_games_owned": 65,
#                 "num_reviews": 16,
#                 "playtime_forever": 5088,
#                 "playtime_last_two_weeks": 0,
#                 "playtime_at_review": 5088,
#                 "last_played": 1737226809
#             },
#             "language": "english",
#             "review": "I've never been into souls like games just know that they are hard and will make me mad but elden ring was my first souls like game ever and ive really enjoyed this game and how beautiful it is and will make sure to play more souls like games although ive never finish it i do plan on finishing the dlc first then the main game last and i do think everyone should give this game a try even they cant find themselves into souls like games :).",
#             "timestamp_created": 1742718173,
#             "timestamp_updated": 1742718173,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.525862038135528564",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191836093",
#             "author": {
#                 "steamid": "76561198795920847",
#                 "num_games_owned": 164,
#                 "num_reviews": 7,
#                 "playtime_forever": 5268,
#                 "playtime_last_two_weeks": 0,
#                 "playtime_at_review": 5268,
#                 "last_played": 1725776915
#             },
#             "language": "english",
#             "review": "Elden Ring took the Souls experience to a grand scale, delivering an open world filled with colossal dungeons, towering bosses, and a narrative crafted with the help of George R.R. Martin. Set in The Lands Between, it allowed unprecedented freedom in exploration while maintaining the brutal difficulty the series is known for. With horseback combat, vast landscapes, and an endless variety of builds, Elden Ring redefined the boundaries of what a Souls game could be. While some critics felt that certain bosses were overly aggressive compared to past titles, the sheer scope and ambition of the game made it an instant classic, widely regarded as one of the best games of the decade.",
#             "timestamp_created": 1743633590,
#             "timestamp_updated": 1743633590,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191687032",
#             "author": {
#                 "steamid": "76561199000996373",
#                 "num_games_owned": 84,
#                 "num_reviews": 18,
#                 "playtime_forever": 11637,
#                 "playtime_last_two_weeks": 5334,
#                 "playtime_at_review": 11637,
#                 "last_played": 1743041712
#             },
#             "language": "english",
#             "review": "Welcome to the Lands Between, Tarnished...\r\n\r\nThis is an amazing Soulsborne you should play at least once in your life. But if you are worried about the difficulty, don't think about it too hard, but it is recommended to have some kind of experience in challenging games. This game can be much more generous on difficulty compared to other Soulsbornes, especially with the completely optional summons you can use to help you fight, and the open-world factor allowing you to come back later if things are too difficult. That doesn't mean it's easy though. But if you are tempted to use summons near the of your journey, I recommend at least trying to learn and get the combat down before instantly resorting to the assist.\r\n\r\nAfter you (hopefully) completed the tutorial found right after the very beginning of the game, you'll be met with a beautiful site and the world this game takes place in, \"the Lands Between.\" The beginning of your journey may seem confusing, but once you start exploring you'll find many areas and things to do.\r\n\r\nThe combat in this game is simple but challenging. But one of the most crucial parts is the dodging. (As with pretty much all Soulsbornes.) Even if you can do some good damage, if you're getting hit every 5-10 seconds, you aren't going to get very far. Trial and error is a part of the game you will experience.\r\n\r\nThe bosses in this game are very good as well. All the main bosses are very unique and fun to fight. (Aside from the possible rage inducing moments you may experience.)\r\n\r\nOne minor issue though is that the NPC quests in this game can be very confusing and sometimes feel extremely difficult to do without a guide online. Another thing is that there is no quest log for any NPCs. So if you start a quest with an NPC, you have to remember it or talk to them again if they are in the same spot to get them to tell you what to do again.\r\n\r\nIn the end, this game isn't perfect by any means. It has some minor flaws. But they don't really take much away from the overall experience. This game is a really good one I recommend if you're looking for a challenging and polished game experience.",
#             "timestamp_created": 1743466333,
#             "timestamp_updated": 1743466333,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191628658",
#             "author": {
#                 "steamid": "76561199135768869",
#                 "num_games_owned": 0,
#                 "num_reviews": 2,
#                 "playtime_forever": 6803,
#                 "playtime_last_two_weeks": 2657,
#                 "playtime_at_review": 6800,
#                 "last_played": 1743419233
#             },
#             "language": "english",
#             "review": "I used to be a huge fan of fps games and never really gave a chance to story-mode based games but im happy i gave a chance on this one. The mechanics in this game have wow'd me and the sheer selections of build you can play and still have fun in is outrageous. playing a dex build i was playing the game on easy mode but even when switching my build to something weaker the game is still fun. The bosses in this game are amazing and the backstory on some of them are deep. my personal favorite boss being Godfrey by far. after completing the base game and DLC i have understood how this game has one game of the year. 10/10 in all aspects and I recommend to all.",
#             "timestamp_created": 1743406020,
#             "timestamp_updated": 1743406020,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191625215",
#             "author": {
#                 "steamid": "76561198082773646",
#                 "num_games_owned": 214,
#                 "num_reviews": 18,
#                 "playtime_forever": 6963,
#                 "playtime_last_two_weeks": 1597,
#                 "playtime_at_review": 6963,
#                 "last_played": 1743399759
#             },
#             "language": "english",
#             "review": "I'm a bit late but I just finished this game. My only regret is I wish I played the game 3 years ago when it first launched.",
#             "timestamp_created": 1743400402,
#             "timestamp_updated": 1743400402,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191530170",
#             "author": {
#                 "steamid": "76561198129482629",
#                 "num_games_owned": 176,
#                 "num_reviews": 4,
#                 "playtime_forever": 10013,
#                 "playtime_last_two_weeks": 0,
#                 "playtime_at_review": 10013,
#                 "last_played": 1737978657
#             },
#             "language": "english",
#             "review": "I never thought I'd be a fan of a Souls game at all. But this game showed me the appeal to Souls-likes. The challenging bosses, the relentless hellscape you are placed in, the unforgiving & lack of coddling that people get so used to while playing games. These sound like they should be cons, but they are some of the games strengths in immersing you in an experience that you cannot find elsewhere. An introductory guide would definitely be needed to figure out your bearings in the beginning, but once you figure that out, I believe this game could easily be one of the best you could ever play. \n\nOnce you get into the game, do not be discouraged in the difficulty of the bosses you meet in the Lands Between, but keep on going. This game rewards perseverance, so remain persistent and you shall be rewarded. \n\nDon't forget to also explore the magnificent and beautiful world that the Lands Between is.",
#             "timestamp_created": 1743306958,
#             "timestamp_updated": 1743306958,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191529148",
#             "author": {
#                 "steamid": "76561199520133591",
#                 "num_games_owned": 0,
#                 "num_reviews": 1,
#                 "playtime_forever": 19159,
#                 "playtime_last_two_weeks": 393,
#                 "playtime_at_review": 19117,
#                 "last_played": 1743648852
#             },
#             "language": "english",
#             "review": "Have played this game 4 times already and it never disappoint me. Different endings. Love it!",
#             "timestamp_created": 1743305833,
#             "timestamp_updated": 1743305833,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191508621",
#             "author": {
#                 "steamid": "76561199388708282",
#                 "num_games_owned": 57,
#                 "num_reviews": 17,
#                 "playtime_forever": 2942,
#                 "playtime_last_two_weeks": 1806,
#                 "playtime_at_review": 2942,
#                 "last_played": 1743283361
#             },
#             "language": "english",
#             "review": "This was my second time 100% the game, still need to replay the DLC. This game is a masterpiece, but I think the boss design peaked with the old hunters DLC and the whole of dark souls 3. Great game, would give anything to play it for the first time again. 100% recommend this game to anyone.\n\nps: I didn't use any summons at all. If you use summons ur a pussy.",
#             "timestamp_created": 1743285085,
#             "timestamp_updated": 1743367992,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191470961",
#             "author": {
#                 "steamid": "76561199799080560",
#                 "num_games_owned": 0,
#                 "num_reviews": 1,
#                 "playtime_forever": 1030,
#                 "playtime_last_two_weeks": 1030,
#                 "playtime_at_review": 422,
#                 "last_played": 1743360154
#             },
#             "language": "english",
#             "review": "dont be fooled ive played this game for hundreds of hours on ps5 and it is AMAZING the world the bosses so good",
#             "timestamp_created": 1743256123,
#             "timestamp_updated": 1743256123,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191419757",
#             "author": {
#                 "steamid": "76561199385300984",
#                 "num_games_owned": 74,
#                 "num_reviews": 12,
#                 "playtime_forever": 2313,
#                 "playtime_last_two_weeks": 2098,
#                 "playtime_at_review": 1244,
#                 "last_played": 1743703781
#             },
#             "language": "english",
#             "review": "although the game is hard, exploring is fun and the feeling you get when you finally defeat a boss is out of this world",
#             "timestamp_created": 1743202229,
#             "timestamp_updated": 1743202229,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191404788",
#             "author": {
#                 "steamid": "76561198278340294",
#                 "num_games_owned": 307,
#                 "num_reviews": 32,
#                 "playtime_forever": 8505,
#                 "playtime_last_two_weeks": 963,
#                 "playtime_at_review": 8505,
#                 "last_played": 1743187864
#             },
#             "language": "english",
#             "review": "Whatever I write about this amazing game, it can never be described in words. I enjoyed playing Lands Beetwen with all its beauty, bosses and all its achievements. Are you stuck on a boss or can't enter an area/location? It's time to wander the Lands Between. It is a magnificent masterpiece with its freedom in every aspect, its mechanics and its atmosphere.\nMusic - 10/10\nGameplay - 10/10\nVisuals - 10/10",
#             "timestamp_created": 1743189008,
#             "timestamp_updated": 1743189008,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         }
#     ],
#     "cursor": "AoIFQFZhheAAAAB0r5PaBQ=="
# }

# %%
print(data.get('reviews')[0].keys())
# Out:
# dict_keys(['recommendationid', 'author', 'language', 'review', 'timestamp_created', 'timestamp_updated', 'voted_up', 'votes_up', 'votes_funny', 'weighted_vote_score', 'comment_count', 'steam_purchase', 'received_for_free', 'written_during_early_access', 'primarily_steam_deck'])

# %%
import json
from requester import Requester
# Out:
# /Users/klemen/Documents/fun/sentiment_analysis/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def scrape_w_ratelimit(app_id, params):
    """
    Scrapes Steam reviews for a given app ID.

    Args:
        app_id (str): The Steam app ID.
        params (dict): A dictionary of parameters to pass to the API.

    Returns:
        dict: A dictionary containing the JSON response from the API.
    """
    url = f"https://store.steampowered.com/appreviews/{app_id}"
    try:
        requester = Requester()
        response = requester.get(url, params=params)
        response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error during request: {e}")
        return None
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return None

# %%
app_id = "1245620"  # Elden Ring App ID
params = {
    "json": "1" # added json parameter
}

data = scrape_w_ratelimit(app_id, params)

if data:
    print(json.dumps(data, indent=4))  # Pretty print the JSON
else:
    print("Failed to retrieve or process data.")
# Out:
# {
#     "success": 1,
#     "query_summary": {
#         "num_reviews": 20,
#         "review_score": 8,
#         "review_score_desc": "Very Positive",
#         "total_positive": 376445,
#         "total_negative": 23129,
#         "total_reviews": 399574
#     },
#     "reviews": [
#         {
#             "recommendationid": "191004925",
#             "author": {
#                 "steamid": "76561198199095678",
#                 "num_games_owned": 58,
#                 "num_reviews": 15,
#                 "playtime_forever": 4739,
#                 "playtime_last_two_weeks": 0,
#                 "playtime_at_review": 4739,
#                 "last_played": 1742748349
#             },
#             "language": "english",
#             "review": "For someone who has never played a souls game, I was impressed at how this game has a massive open world with a cryptic story-line and different endings based on different actions performed.  The hardest part of this game wasn't facing the demigods with supernatural powers, it was overcoming my fear of giant flying insects and my fear of heights by playing this game. Thanks to this game, I no longer have acrophobia and entomophobia.\n\n10/10 would recommend to overcome your fears.",
#             "timestamp_created": 1742748749,
#             "timestamp_updated": 1742748749,
#             "voted_up": true,
#             "votes_up": 45,
#             "votes_funny": 8,
#             "weighted_vote_score": "0.789432346820831299",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192306771",
#             "author": {
#                 "steamid": "76561198443820366",
#                 "num_games_owned": 293,
#                 "num_reviews": 9,
#                 "playtime_forever": 29658,
#                 "playtime_last_two_weeks": 4314,
#                 "playtime_at_review": 28913,
#                 "last_played": 1744328903
#             },
#             "language": "english",
#             "review": "Let me make it clear that I absolutely love this game. The hours I've put into it are the very reason I'm leaving a negative review.\r\n\r\nThis game in its current state has a huge hacking problem, that needs to be addressed. I spent over 70 hours on a character that got hacked and its save corrupted because of Easy Anti-Cheat workarounds. FromSoft needs to address this ASAP, as there is no way to recover that data.",
#             "timestamp_created": 1744134504,
#             "timestamp_updated": 1744134504,
#             "voted_up": false,
#             "votes_up": 18,
#             "votes_funny": 1,
#             "weighted_vote_score": "0.66473466157913208",
#             "comment_count": 1,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191743794",
#             "author": {
#                 "steamid": "76561199007874518",
#                 "num_games_owned": 230,
#                 "num_reviews": 34,
#                 "playtime_forever": 8596,
#                 "playtime_last_two_weeks": 3323,
#                 "playtime_at_review": 7047,
#                 "last_played": 1744444538
#             },
#             "language": "english",
#             "review": "[h2] Honest Review [/h2]\nPeak game, after approx 110++ hours i finally become the elden ring. It is a classic soulslike game the plus is you got all variant and playstyle. While DS series seems to be a melee based combat, at least for me. Elden ring step up so magic, melee, bow, etc playable. \n\nTLDR : git gud for me\n\n[h2] What can be improved?[/h2]\nI would say that i crazily simp for Rya. Kinda dissapointing that they don't include Rya ending's. This alone make the game a  9/10. Hopefully they do an update to include Rya as one of the ending.",
#             "timestamp_created": 1743531423,
#             "timestamp_updated": 1743531423,
#             "voted_up": true,
#             "votes_up": 6,
#             "votes_funny": 2,
#             "weighted_vote_score": "0.583479940891265869",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "190408547",
#             "author": {
#                 "steamid": "76561198049009386",
#                 "num_games_owned": 9246,
#                 "num_reviews": 75,
#                 "playtime_forever": 7356,
#                 "playtime_last_two_weeks": 0,
#                 "playtime_at_review": 7356,
#                 "last_played": 1679748750
#             },
#             "language": "english",
#             "review": "This is the first Souls-like game I have ever played. I was a bit skeptical about it, but everything changed as soon as I started the game.\n\nThe game felt hard at the beginning, but once you understand what needs to be done, how the combat mechanics work, and study the difficult bosses after a few deaths, it becomes much more enjoyable.\n\nThe universe FromSoftware created is beautiful, with great level design and well-crafted bosses. There are a few repetitive dungeons, areas, and bosses, and at times the game feels a bit stretched, but I can tolerate that because it's not overdone.\n\nThere is a huge variety of builds and weapons, which is very useful if you plan to have more than one playthrough. On top of that, the game offers a vast number of hidden collectibles and secrets.\n\nIt's a very special game, and I would highly recommend it to action-adventure RPG lovers. This isn't structured exactly like previous Souls games, you have a massive open-world map with stunning locations and excellent level design.",
#             "timestamp_created": 1742163284,
#             "timestamp_updated": 1742163284,
#             "voted_up": true,
#             "votes_up": 7,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.564307153224945068",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192143902",
#             "author": {
#                 "steamid": "76561199815109536",
#                 "num_games_owned": 0,
#                 "num_reviews": 4,
#                 "playtime_forever": 960,
#                 "playtime_last_two_weeks": 960,
#                 "playtime_at_review": 960,
#                 "last_played": 1743936647
#             },
#             "language": "english",
#             "review": "Overall, I'm binning the game and moving on because I'm simply not enjoying it enough. I understand that a lot of my complaints apply to the Soulsborne series as a whole, so it seems pretty clear that the series is not for me.\r\n\r\nI really like that just about every mob can be a real threat and should be treated as such, and that you really have to be conscious about not letting yourself get surrounded. Some of the special weapon moves can feel really satisfying if pulled off. But that's about the last good thing I have to say about the combat.\r\n\r\nUltimately, I think the controls just feel too jank for what the game demands of you, especially against the bosses. Dodge rolling feels VERY inconsistent, as does whether or not my character will decide to drink their health potion when I press the button. I really hated getting stunlocked by bosses too. I get that part of the challenge is avoiding the initial hit that leads to the combo, but it made me feel helpless, rather than motivating me to improve.\r\n\r\nThe jank also extends to the exploration. The platforming feels absolutely awful, whether on foot or on horseback. The amount of times where it was literally the intended path to take a risky-looking jump off an innocuous-looking ledge bordered on absurd. It's crazy to me that a game that advertises its open world as including an interesting amount of verticality would contain no climbing mechanics or ways to interact with ledges besides awkwardly running off them. It was equally crazy to me that fast travel was the only way out of the Leonine Misbegotten arena. Actively requiring fast travel because there's no other way to exit an area feels like a violation of the open world promise.\r\n\r\nThe runes/souls system for levelling up and shopping is of course excellent, though the corpse running mechanic feels like it makes a lot less sense in an open world game as opposed to earlier, linear entries. Nothing discourages exploration like returning to the same area over and over again. I feel that the improvements I got from levelling up were far too granular, and I never really felt any more powerful leaving a Site of Grace because I saw a number increase from 103 to 105.\r\n\r\nMy final gripe is the way in which information is presented. NPCs speaking in cryptic riddles can be cool for dishing out lore, but I shouldn't be able to accept a quest and have no idea what I've actually been asked to do. I'm sure I won't be the first to complain that there is no quest log, which seems to be a pointlessly stubborn decision for a game of this scale. The menus are horrendous to navigate, and make very little sense. The game does not seem at all interested in teaching you its mechanics either. Most of what I learned was from wikis and Reddit posts, because the game was too obtuse to give me the info I needed.\r\n\r\nAll of this is a huge shame, because I really wanted to like the game. I was excited to see what all the fuss was about. It feels like this would be an incredible experience for anyone who already loves the Souls series, but it was just too hostile for this hapless first-timer.",
#             "timestamp_created": 1743951430,
#             "timestamp_updated": 1743951430,
#             "voted_up": false,
#             "votes_up": 26,
#             "votes_funny": 17,
#             "weighted_vote_score": "0.549299538135528564",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192179420",
#             "author": {
#                 "steamid": "76561198249083520",
#                 "num_games_owned": 0,
#                 "num_reviews": 3,
#                 "playtime_forever": 17136,
#                 "playtime_last_two_weeks": 1916,
#                 "playtime_at_review": 16410,
#                 "last_played": 1744444791
#             },
#             "language": "english",
#             "review": "I would give this games a side-ways thumb if I could. But I'll just give a thumbs down because I hate this game as much as I love it. Its wonderfully mystical but shamelessly unfair. \n\nMy frustrations with the game can be summed up as \"rules for thee but not for me.\" Bosses like Maliketh and Margott keep on jumping around, retreating and relentlessly attacks like they have infinite stamina; enemies like the Royal Revenant, Misbegottens, Azula Beastmen and Banished Knights can also attack overly-aggressively and endlessly. NPC enemies like Bernahl, Vyke and Okina can hyper armor through your attacks and retaliate almost immediately after you flinch them. Them and regular enemies have infinite FP to spam as much spells and art of wars as they want. Glintstone Sorcerers are annoying for this reason paired with always coming in groups. Cast speed can also be lightning fast like how the Night's Cavalry can call back their horse faster than your fist weapons can land. Landing hits or punishes can be annoying with your toothpick-like range and given how agile bosses are like Gargoyles, Maliketh and even Loretta with how often they move around with their horse. Boss' also being bigger than you means they always have a larger range than you paired with generous tracking to catch you. \n\nThe game simply sides with the enemies and bosses, even when they're NPCs with player-esque models. Meanwhile you're still dealing with stamina, bestowed a singular jump button as a pittance and the Dark Wood Grain Ring hasn't been seen since Dark Souls I. You get interrupted out of your attack by a sneeze. Can't even land projectiles like the kukri half the time since many enemies are programmed to auto-dodge and the lock-on is straight up unreliable for moving enemies. Even when dumping stats into stamina, your combo ends and recovers while enemies can (again) keep relentlessly attacking. You'll just find yourself being knocked around like a paddle-ball regardless of damage taken, having to heal and then it happening all over again due to input-read. Draconic Tree Sentinel will just keep spitting fireballs if you heal; Ancient Dragons swing and spam lightning to knock you around a lot. The Attacks that seem like they have adequate recovery to punish the enemies are actually bait so enemies can follow-up to punish you trying to punish them; if you don't punish, they'll just not do anything and recover. I'm looking at you Margit. \"You don't get to punish. Only I get to punish and play the game\" kind of despicable attitude. You'll just be gaslit by the game or its advocates to not be 'greedy,' despite being a starving child compared to what the enemies and bosses are fed. \n\nAnd yet I can't help but keep playing this game. The unremarkable rpg damage numbers when spamming my spike balls or twin knight's resolve Giant-Crusher jumping r2 make my monkey brain go \"UGH UGH.\" Still recommend if you've never played it before...",
#             "timestamp_created": 1743980741,
#             "timestamp_updated": 1743980741,
#             "voted_up": false,
#             "votes_up": 5,
#             "votes_funny": 1,
#             "weighted_vote_score": "0.542849898338317871",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191088636",
#             "author": {
#                 "steamid": "76561198007716247",
#                 "num_games_owned": 0,
#                 "num_reviews": 14,
#                 "playtime_forever": 4825,
#                 "playtime_last_two_weeks": 746,
#                 "playtime_at_review": 2682,
#                 "last_played": 1744275876
#             },
#             "language": "english",
#             "review": "fantastic game. played it for 250+ hours on PS5 on release.\r\n\r\nbut, 3 years later, there are some obvious problems that reduce my enjoyment:\r\n\r\n- mouse/keyboard controls are awful. cycling through abilities/items is tedious. why can't there be a hotbar (i.e. keys 1-9) for that? this is clearly a game made for controller, explicitly for controllers with back paddles (unless you want to \"claw grip\". ouch.)\r\n- no quest log, really? i can't remember what some random NPC told me 10-20 hours ago. i don't need quest markers, just a log where i can read up on what the NPCs said. if it isn't in-game people will just look it up on the internet.\r\n- no maps in dungeons. again, people will just look it up on the internet.\r\n- UI-\"Toasts\" must be dismissed manually, even in combat. wtfman!\r\n- \"just run past 90% of the enemies\" gameplay.\r\n- \"the princess is in another castle\" moment after the first time reaching the erdtree.\r\n- skeletons are cumbersome without certain weapons (Golden Epitaph etc.)\r\n- lots of unfair and cheesy enemy attacks that stunlock you to death.\r\n- lock-on system is bad, especially against larger enemies.\r\n- sometimes questionable hit box detection.\r\n- the worst enemy is the camera.\r\n- \"catch flame\" is still OP :)\r\n\r\nbut, still a 9/10 and a must-play. the art-/characterdesign is superb, the music is brilliant, exploration gets rewarded and riding torrent feels just good. also, there are quite a bunch of good mods for the PC version.",
#             "timestamp_created": 1742838093,
#             "timestamp_updated": 1742838093,
#             "voted_up": true,
#             "votes_up": 3,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.542483627796173096",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191123689",
#             "author": {
#                 "steamid": "76561198363109630",
#                 "num_games_owned": 167,
#                 "num_reviews": 36,
#                 "playtime_forever": 1979,
#                 "playtime_last_two_weeks": 455,
#                 "playtime_at_review": 641,
#                 "last_played": 1743825068
#             },
#             "language": "english",
#             "review": "As amazing as everyone says. Great visuals, fun combat, and a fantastic soundtrack. My favorite thing about the game, is the incredibly deep character creation options, the possibilities are nearly endless. Playing with friends is a true Joy, and I can't recommend this game enough!",
#             "timestamp_created": 1742873669,
#             "timestamp_updated": 1742873669,
#             "voted_up": true,
#             "votes_up": 2,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.542168676853179932",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192535075",
#             "author": {
#                 "steamid": "76561198977174096",
#                 "num_games_owned": 62,
#                 "num_reviews": 5,
#                 "playtime_forever": 17054,
#                 "playtime_last_two_weeks": 1906,
#                 "playtime_at_review": 17054,
#                 "last_played": 1744322122
#             },
#             "language": "english",
#             "review": "Okay, after 3 years, I have finally beat elden ring in less than 2 weeks. and here is my constructive criticism about the game. I have a love and hate relationship with elden ring, but end up with loving the game more than hating apparently, because I keep playing it.\n\nThe game itself has alot of content and if you want to, you can be combat ready for NG+ as it's getting harder over time. (NG+ 1 was mad easy than you start the very NG if you tell me) The game has left with good and very challanging content and makes the gameplay quite difficult. So here we go to the constructive criticism.\n\n1. The map is so HUGE that the delevopers must be delusional to not add guides in the game itself on where to go, what quests are nearby and what quests you can accept. I have looked up a gazilion times on youtube and google for guides on where to go, because the game doesn't offer me that which left me 3 years of not playing the game.\n\n2. All bosses have input reading which is basically an AI added feature in the boss that reads your average combat style and knows exactly when to counter your attacks and the moments to heal.\n\n3. the traditional fromsoft dodges are very unforgiving. The ''dodge'' has exactly 1 second to dodge projectiles and attacks, so learning how to dodge is based the attacks on the enemy. The AOE's on some bosses are so overpowered that some of them aren't even dodgable and then you will end up dead eventually.\n\n4. Bosses with delay attacks. I've said enough.",
#             "timestamp_created": 1744412168,
#             "timestamp_updated": 1744412168,
#             "voted_up": false,
#             "votes_up": 2,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.541984736919403076",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "190816321",
#             "author": {
#                 "steamid": "76561199236995420",
#                 "num_games_owned": 27,
#                 "num_reviews": 2,
#                 "playtime_forever": 15241,
#                 "playtime_last_two_weeks": 117,
#                 "playtime_at_review": 15123,
#                 "last_played": 1743265850
#             },
#             "language": "english",
#             "review": "---{ Graphics }---\n\u2610 You forget what reality is\n\u2611 Beautiful\n\u2610 Good\n\u2610 Decent\n\u2610 Bad\n\u2610 Don\u2018t look too long at it\n\u2610 MS-DOS\n\n---{ Gameplay }---\n\u2611 Very good\n\u2610 Good\n\u2610 It's just gameplay\n\u2610 Mehh\n\u2610 Watch paint dry instead\n\u2610 Just don't\n\n---{ Audio }---\n\u2610 Eargasm\n\u2611 Very good\n\u2610 Good\n\u2610 Not too bad\n\u2610 Bad\n\u2610 I'm now deaf\n\n---{ Audience }---\n\u2610 Kids\n\u2611 Teens\n\u2611 Adults\n\u2610 Grandma\n\n---{ PC Requirements }---\n\u2610 Check if you can run paint\n\u2610  Potato\n\u2611 Decent\n\u2610 Fast\n\u2610 Rich boi\n\u2610 Ask NASA if they have a spare computer\n\n---{ Difficulty }---\n\u2610 Just press 'W'\n\u2610 Easy\n\u2610 Easy to learn / Hard to master\n\u2610 Significant brain usage\n\u2611 Difficult\n\u2610 Dark Souls\n\n---{ Story }---\n\u2610 No Story\n\u2610 Some lore\n\u2610 Average\n\u2610 Good\n\u2610 Lovely\n\u2611 It'll replace your life\n\n---{ Game Time }---\n\u2610 Long enough for a cup of coffee\n\u2610 Short\n\u2610 Average\n\u2611 Long\n\u2610 To infinity and beyond\n\n---{ Price }---\n\u2610 It's free!\n\u2611 Worth the price\n\u2610 If it's on sale\n\u2610 If u have some spare money left\n\u2610 Not recommended\n\u2610 You could also just burn your money\n\n---{ Bugs }---\n\u2610 Never heard of\n\u2611 Minor bugs\n\u2610 Can get annoying\n\u2610 ARK: Survival Evolved\n\u2610 The game itself is a big terrarium for bugs\n",
#             "timestamp_created": 1742576484,
#             "timestamp_updated": 1742576484,
#             "voted_up": true,
#             "votes_up": 2,
#             "votes_funny": 1,
#             "weighted_vote_score": "0.541984736919403076",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192011203",
#             "author": {
#                 "steamid": "76561199069413379",
#                 "num_games_owned": 0,
#                 "num_reviews": 56,
#                 "playtime_forever": 3552,
#                 "playtime_last_two_weeks": 930,
#                 "playtime_at_review": 3381,
#                 "last_played": 1744427021
#             },
#             "language": "english",
#             "review": "Really not hard but it does get really annoying.\r\n\r\nit's just going to be a lot of enemies that are fast, do a lot of damage, and tank everything. It just gets annoying having to clear things out for poor paced story and exploration. \r\n\r\nAlso what is with constantly killing off characters off screen. Did you guys poorly translate important dialogue and hints again?",
#             "timestamp_created": 1743823924,
#             "timestamp_updated": 1743823924,
#             "voted_up": false,
#             "votes_up": 5,
#             "votes_funny": 3,
#             "weighted_vote_score": "0.541942477226257324",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192428799",
#             "author": {
#                 "steamid": "76561198034743692",
#                 "num_games_owned": 774,
#                 "num_reviews": 7,
#                 "playtime_forever": 9890,
#                 "playtime_last_two_weeks": 6061,
#                 "playtime_at_review": 9890,
#                 "last_played": 1744205767
#             },
#             "language": "english",
#             "review": "finished game fun bosses difficulty, beautiful open world, masterpiece 10/10",
#             "timestamp_created": 1744291508,
#             "timestamp_updated": 1744291508,
#             "voted_up": true,
#             "votes_up": 2,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.541284441947937012",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192443156",
#             "author": {
#                 "steamid": "76561198851700562",
#                 "num_games_owned": 405,
#                 "num_reviews": 10,
#                 "playtime_forever": 2460,
#                 "playtime_last_two_weeks": 168,
#                 "playtime_at_review": 2298,
#                 "last_played": 1744443503
#             },
#             "language": "english",
#             "review": "Locks you at 60fps, and DOESN'T have Ultra Wide support... \r\n\r\nFor a game released in 2022 AND is $90 AUD, this is extremely disappointing.\r\n\r\nNot only that, but using a tool to EXCLUSIVELY uncap your fps is bannable.\r\n\r\nThe game is fun, but being restricted like this completely ruins it.\r\n\r\nThanks for nothing Fromsoft.",
#             "timestamp_created": 1744305155,
#             "timestamp_updated": 1744305155,
#             "voted_up": false,
#             "votes_up": 4,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.528925597667694092",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "190326624",
#             "author": {
#                 "steamid": "76561197970525021",
#                 "num_games_owned": 460,
#                 "num_reviews": 97,
#                 "playtime_forever": 1983,
#                 "playtime_last_two_weeks": 145,
#                 "playtime_at_review": 251,
#                 "deck_playtime_at_review": 251,
#                 "last_played": 1743682365
#             },
#             "language": "english",
#             "review": "Don't lisyen to people who try to shame you for not liking games that are too hard for you. If you like the challenge, go for it, make it hard. If you don't, you have options to make life easier. This game gives you the tools to tailor the game to your preferences and you should use things as you see fit. \r\nThe gameplay is a bit stiff and clunky. Kind of like an indie title using stock plugins. Not bad so much as needing an adjustment period. The graphics are nothing special and the pacing glacial.\r\nWhat this game has going against it, however, pales in comparison to the whole. As a package, it's so, so hard to dislike this. The atmosphere keeps you hooked, the design of the spaces makes you cautious, yet still willing to push on. Any setbacks you have can be put off while you work on getting stronger and still engaging with the game fully. The side quests are not, they are all integral to the whole.\r\nTruly a game that is not for everybody, yet appealing to so, so many. Some people may put you off, but please remember that your game is yours. Play it how you enjoy it.",
#             "timestamp_created": 1742099147,
#             "timestamp_updated": 1742099147,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.528301894664764404",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": true
#         },
#         {
#             "recommendationid": "190730897",
#             "author": {
#                 "steamid": "76561197984170060",
#                 "num_games_owned": 866,
#                 "num_reviews": 256,
#                 "playtime_forever": 23931,
#                 "playtime_last_two_weeks": 0,
#                 "playtime_at_review": 23764,
#                 "last_played": 1742509265
#             },
#             "language": "english",
#             "review": "I really enjoyed my time in this game. I spent about 400 hours on a _single_ playthrough, and not a moment of it felt like it dragged or overstayed its welcome, nor did the hours matter at all. \r\n\r\nThe landscapes were gorgeous and unique, each one filled me with a tapestry of emotions \u2014 curiosity, dread, expectation, apprehension, anticipation, excitement, fear, the whole gamut. It's a unique mix that I haven't experienced in other games. \r\n\r\nThe world constantly unveiled surprises around every corner, and the game would have a subtle way of defying the things I would begin to treat as expected; just when I think I've managed to 'figure out' a certain enemy type or a zone, a new variation is thrown at me that I have to overcome. \r\n\r\nConquering these challenges felt rewarding, but right away became a baseline setup for the next challenge to overcome. I realize a lot of this is quite abstract and intangible but I had to express it, and I see the other reviews also trying to do the same thing. \r\n\r\nThe type of environment that really appeals to me is being alone (I don't like playing with others), I like rich fantasy landscapes, I like castles and dungeons, ruins, exploring, finding secrets. This world gives me all of that. There's a pervasive sense of exploration and loneliness, within a realm that is hostile and beautiful. The accompanying music is often tenuous and haunting, enhancing the atmospheric experience. \r\n\r\nThe other really nice thing about the game, is I can play it and 'beat' it in so many different ways. There are so many tools available and it's entirely up to me whether to use or ignore them, and that makes for a unique playthrough. There are dozens of weapons, armor types, spells, skills, summons, recipes. I simply chose the playstyle that I liked the most. I didn't really go for consumables, but I did like summons. I found lots of cool looking weapons, but only the pickaxe felt the best to me, the way it just smacks the enemies down with absolute piercing authority.",
#             "timestamp_created": 1742496650,
#             "timestamp_updated": 1742496650,
#             "voted_up": true,
#             "votes_up": 2,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.52649378776550293",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "190966366",
#             "author": {
#                 "steamid": "76561199122290030",
#                 "num_games_owned": 65,
#                 "num_reviews": 16,
#                 "playtime_forever": 5088,
#                 "playtime_last_two_weeks": 0,
#                 "playtime_at_review": 5088,
#                 "last_played": 1737226809
#             },
#             "language": "english",
#             "review": "I've never been into souls like games just know that they are hard and will make me mad but elden ring was my first souls like game ever and ive really enjoyed this game and how beautiful it is and will make sure to play more souls like games although ive never finish it i do plan on finishing the dlc first then the main game last and i do think everyone should give this game a try even they cant find themselves into souls like games :).",
#             "timestamp_created": 1742718173,
#             "timestamp_updated": 1742718173,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.525862038135528564",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "191460314",
#             "author": {
#                 "steamid": "76561198045112814",
#                 "num_games_owned": 110,
#                 "num_reviews": 12,
#                 "playtime_forever": 1726,
#                 "playtime_last_two_weeks": 0,
#                 "playtime_at_review": 1726,
#                 "last_played": 1742659140
#             },
#             "language": "english",
#             "review": "[h1][b]Elden Ring - Where Beauty Meets Brutality (and My Pride Gets Repeatedly Punched)[/b][/h1]\n\nOh, Elden Ring. What a masterpiece you are! FromSoftware has truly outdone themselves with this one\u2014like they handed Picasso a game engine and said, \"Make something that'll make people cry.\" And boy, does it make you cry rivers.\n\nThe graphics? [b]Stunning.[/b] Seriously, I\u2019ve spent more time staring at the sunset over Limgrave than actually playing the game. The landscapes are so breathtakingly beautiful that every time I respawn after dying to some random frog or pot-wielding grandma, I feel like I\u2019m in an art gallery where someone keeps punching me in the face. It\u2019s poetic. Truly poetic.\n\nAnd the gameplay? Stellar. The combat system is tight, responsive, and deeply satisfying when you finally nail that perfect parry against a giant knight who's been curb-stomping you for hours. Every victory feels earned, even if it took me 47 tries to beat a tree stump that might have been sentient. There\u2019s just something magical about going from \u201cI hate everything\u201d to \u201cI am the Elden Lord!\u201d in under five seconds.\n\nNow let\u2019s talk about the difficulty. Oh, sweet merciful heavens, this game is brutal. But here\u2019s the twist\u2014it\u2019s fun! Like, really fun. Sure, I\u2019ve screamed at my screen more times than I can count because yet another invisible skeleton decided to ruin my day, but there\u2019s always this little voice inside me saying, \u201cCome on, you got this!\u201d [i]Spoiler alert: I didn\u2019t get this.[/i] Not most of the time anyway. But hey, dying is half the experience, right? [i]Right?![/i]\n\nIn conclusion, Elden Ring is a love letter to gamers who enjoy being humbled by their own incompetence while marveling at jaw-dropping visuals and flawless mechanics. If you\u2019re looking for a challenge that\u2019ll test your patience, skill, and will to live, look no further. Just be prepared to lose a few hundred hours of your life\u2014and possibly your sanity\u2014to a video game that somehow makes failure feel rewarding.",
#             "timestamp_created": 1743246325,
#             "timestamp_updated": 1743246346,
#             "voted_up": true,
#             "votes_up": 6,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.574434936046600342",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192462239",
#             "author": {
#                 "steamid": "76561198147589000",
#                 "num_games_owned": 84,
#                 "num_reviews": 11,
#                 "playtime_forever": 5765,
#                 "playtime_last_two_weeks": 3108,
#                 "playtime_at_review": 5389,
#                 "last_played": 1744399670
#             },
#             "language": "english",
#             "review": "game is bugged plz tell me when you figs game !!! i am poor man from india i work uber 12 hours and i have little time to play in my taxi last boss is buggage pls valve fix game",
#             "timestamp_created": 1744324902,
#             "timestamp_updated": 1744324902,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 1,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192378764",
#             "author": {
#                 "steamid": "76561199215034219",
#                 "num_games_owned": 0,
#                 "num_reviews": 1,
#                 "playtime_forever": 3548,
#                 "playtime_last_two_weeks": 837,
#                 "playtime_at_review": 3492,
#                 "last_played": 1744295666
#             },
#             "language": "english",
#             "review": "Amazing game, though sometimes unfair, it has a wonderful world built by experts, bossfights that you won't forget no matter how many concussions you give yourself while playing. While the online is buggy, it atleast exists and if feels amazing to play with friends. Elden Ring has an amazing community to go with, all items, enemies, bosses are available online. Anyone who dislikes this game probably have a skill issue, though there are certainly annoying parts (mostly due to my skill issues). Hope you enjoy!",
#             "timestamp_created": 1744222054,
#             "timestamp_updated": 1744222054,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         },
#         {
#             "recommendationid": "192329939",
#             "author": {
#                 "steamid": "76561198029084277",
#                 "num_games_owned": 457,
#                 "num_reviews": 37,
#                 "playtime_forever": 10150,
#                 "playtime_last_two_weeks": 5472,
#                 "playtime_at_review": 10007,
#                 "last_played": 1744410530
#             },
#             "language": "english",
#             "review": "What a game! Just completed main story. DLC later, so this will cover only the main game.\nI'll keep things spoiler-free or be intentionally vague to make my point without telling the details.\nMy first blind playthrough, no guides, except for some info on NPC quests, mouse and keyboard.\n\n[h2]Elden Ring - main game[/h2]\n[h3]Positives - First off, joy![/h3]\n- Lets talk about the elephant in the game - open world. This is a first in FromSoft souls games and it brings mostly positives, but also a couple of blunders, more on those later. This open world is so much better than in most other such games, because it allows and encourages you to find things on your own, you only get a small hint on the direction in which the main story is going and after that you decide your adventure, no question marks on the map, no outposts, no busy work lame activities. Just exploration, beautiful views everywhere and deadly fights. Oh and the flow is seamless, because you don't need to run back and forth to \"take on a mission\", then slowly get to the destination for things to start happening, in Elden Ring events happen as you go and you return to hub only when you want to.\n- Level designers went nuts this time, the big castle you encounter early on was so massive and cleverly designed that I felt a bit overwhelmed and took my sweet time to look in every corner of it and was not disappointed, clearly THE best castle design I've ever seen in a game. Later on it was surpassed by the city, but that location I think was actually a bit too much, though I still enjoyed it. If you have topographical cretinism you're gonna be in trouble.\n- A lot of spectacular boss fights, one of them went straight into my top 3 of all FromSoft souls games.\n- Many weapons, arts, summons, magic to choose from, so everyone will find something to their liking.\n- Amazing art design, with HDR enabled this game looks like every frame a painting.\n- Controls are fine, I've always played with M&K, so only dedicated jumping button was new to me. I've put jumping on a side button on the mouse, disabled the auto panning of the camera and got gud pretty quickly after that, thanks to the Erdtree Sentry (golden knight).\n\n[h3]Negatives - Why is it always dung?[/h3]\n- NPC stories and quests were always vague in souls games and this time the vast open world only exacerbated the issue. Previous games were smaller and more linear, so if you were paying attention you'd probably cover many of the quests and even complete some of them, in Elden ring there could be tens of hours between quest starting point and its next step, if you are like me and take your time exploring. By that time you'll probably forget who was that NPC or what they wanted, there is no log to keep track, so you either take notes yourself or consult a wiki, which is lame, I hate doing that, but in this case it's almost mandatory. You could also go somewhere the game didn't thought you'd go so early and trigger some events that will skip a lot of steps in the stories. There are also hidden triggers of which you have no idea and so on. It's a mess. I miraculously found out some of the events by pure luck and that's me being thorough.\n- Boss fights quantity over quality and the challenge aspect. Another issue of the open world pattern. Some of them are repeating a lot with minor changes. They are like filler bosses. After the first major boss before entering the castle, Elden Ring somewhat loses its challenge aspect in boss fights until the last 20% of the game and the infamous Malenia with her FUCKING combo, seriously, that would be a fantastic boss, but that one cheap combo she does is infuriating. Other than that it was a good fight and the second one after the first major boss where I had to be fully focused to overcome. I died here a lot. A few other bosses were also difficult, but nowhere near these two, at least for me.\n- 60 FPS lock, no ultrawide support, funny thing is game does  ...
#             "timestamp_created": 1744159874,
#             "timestamp_updated": 1744161055,
#             "voted_up": true,
#             "votes_up": 1,
#             "votes_funny": 0,
#             "weighted_vote_score": "0.523809552192687988",
#             "comment_count": 0,
#             "steam_purchase": true,
#             "received_for_free": false,
#             "written_during_early_access": false,
#             "primarily_steam_deck": false
#         }
#     ],
#     "cursor": "AoIFQFZhheAAAABzjdfdBQ=="
# }
